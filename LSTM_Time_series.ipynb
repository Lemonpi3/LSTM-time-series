# %% [markdown]
# <a href="https://colab.research.google.com/github/Lemonpi3/LSTM-time-series/blob/main/LSTM_Time_series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import os
import pandas as pd
import numpy as np

# %%
zip_path = tf.keras.utils.get_file(
    origin='https://storage.googleapis.com/tensorflow/tf-keras-datasets/jena_climate_2009_2016.csv.zip',
    fname='jena_climate_2009_2016.csv.zip',
    extract=True)
csv_path, _ = os.path.splitext(zip_path)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/jena_climate_2009_2016.csv.zip
# 13574144/13568290 [==============================] - 0s 0us/step
# 13582336/13568290 [==============================] - 0s 0us/step

# %%
df = pd.read_csv(csv_path)
df
# Out:
#                   Date Time  p (mbar)  ...  max. wv (m/s)  wd (deg)
# 0       01.01.2009 00:10:00    996.52  ...           1.75     152.3
# 1       01.01.2009 00:20:00    996.57  ...           1.50     136.1
# 2       01.01.2009 00:30:00    996.53  ...           0.63     171.6
# 3       01.01.2009 00:40:00    996.51  ...           0.50     198.0
# 4       01.01.2009 00:50:00    996.51  ...           0.63     214.3
# ...                     ...       ...  ...            ...       ...
# 420546  31.12.2016 23:20:00   1000.07  ...           1.52     240.0
# 420547  31.12.2016 23:30:00    999.93  ...           1.92     234.3
# 420548  31.12.2016 23:40:00    999.82  ...           2.00     215.2
# 420549  31.12.2016 23:50:00    999.81  ...           2.16     225.8
# 420550  01.01.2017 00:00:00    999.82  ...           1.96     184.9
#
# [420551 rows x 15 columns]

# %%
df = df[5::6]
df
# Out:
#                   Date Time  p (mbar)  ...  max. wv (m/s)  wd (deg)
# 5       01.01.2009 01:00:00    996.50  ...           0.63     192.7
# 11      01.01.2009 02:00:00    996.62  ...           0.63     190.3
# 17      01.01.2009 03:00:00    996.84  ...           0.63     167.2
# 23      01.01.2009 04:00:00    996.99  ...           0.38     240.0
# 29      01.01.2009 05:00:00    997.46  ...           0.88     157.0
# ...                     ...       ...  ...            ...       ...
# 420521  31.12.2016 19:10:00   1002.18  ...           1.36     190.6
# 420527  31.12.2016 20:10:00   1001.40  ...           1.92     225.4
# 420533  31.12.2016 21:10:00   1001.19  ...           1.56     158.7
# 420539  31.12.2016 22:10:00   1000.65  ...           0.68     216.7
# 420545  31.12.2016 23:10:00   1000.11  ...           1.00     202.6
#
# [70091 rows x 15 columns]

# %%
df.index = pd.to_datetime(df['Date Time'], format = '%d.%m.%Y %H:%M:%S')
df[:26]
# Out:
#                                Date Time  p (mbar)  ...  max. wv (m/s)  wd (deg)
# Date Time                                           ...
# 2009-01-01 01:00:00  01.01.2009 01:00:00    996.50  ...           0.63     192.7
# 2009-01-01 02:00:00  01.01.2009 02:00:00    996.62  ...           0.63     190.3
# 2009-01-01 03:00:00  01.01.2009 03:00:00    996.84  ...           0.63     167.2
# 2009-01-01 04:00:00  01.01.2009 04:00:00    996.99  ...           0.38     240.0
# 2009-01-01 05:00:00  01.01.2009 05:00:00    997.46  ...           0.88     157.0
# 2009-01-01 06:00:00  01.01.2009 06:00:00    997.71  ...           0.50     146.0
# 2009-01-01 07:00:00  01.01.2009 07:00:00    998.33  ...           2.88     348.8
# 2009-01-01 08:00:00  01.01.2009 08:00:00    999.17  ...           1.25     213.9
# 2009-01-01 09:00:00  01.01.2009 09:00:00    999.69  ...           0.63     202.2
# 2009-01-01 10:00:00  01.01.2009 10:00:00   1000.27  ...           3.00     292.6
# 2009-01-01 11:00:00  01.01.2009 11:00:00   1000.87  ...           3.38     269.6
# 2009-01-01 12:00:00  01.01.2009 12:00:00   1000.30  ...           2.63     184.4
# 2009-01-01 13:00:00  01.01.2009 13:00:00   1000.03  ...           1.25     187.3
# 2009-01-01 14:00:00  01.01.2009 14:00:00    999.81  ...           2.00     144.0
# 2009-01-01 15:00:00  01.01.2009 15:00:00    999.88  ...           1.88     134.9
# 2009-01-01 16:00:00  01.01.2009 16:00:00    999.94  ...           2.13     145.5
# 2009-01-01 17:00:00  01.01.2009 17:00:00   1000.17  ...           1.63     142.2
# 2009-01-01 18:00:00  01.01.2009 18:00:00   1000.16  ...           1.00     183.7
# 2009-01-01 19:00:00  01.01.2009 19:00:00   1000.22  ...           0.75     176.7
# 2009-01-01 20:00:00  01.01.2009 20:00:00   1000.22  ...           1.13     195.2
# 2009-01-01 21:00:00  01.01.2009 21:00:00   1000.19  ...           0.75     206.3
# 2009-01-01 22:00:00  01.01.2009 22:00:00   1000.00  ...           0.63     175.7
# 2009-01-01 23:00:00  01.01.2009 23:00:00    999.77  ...           1.00     219.3
# 2009-01-02 00:00:00  02.01.2009 00:00:00    999.59  ...           0.88     155.0
# 2009-01-02 01:00:00  02.01.2009 01:00:00    999.34  ...           1.00     148.1
# 2009-01-02 02:00:00  02.01.2009 02:00:00    998.93  ...           0.88     209.8
#
# [26 rows x 15 columns]

# %%
temp = df['T (degC)']
temp.plot()

# %%
def df_to_X_y(df, window_size):
  df_as_np = df.to_numpy()
  X = []
  y = []
  for i in range(len(df_as_np)-window_size):
    row = [[a] for a in df_as_np[i:i+5]]
    X.append(row) 
    label = df_as_np[i+5]
    y.append(label)
  return np.array(X), np.array(y)

# %%
WINDOW_SIZE = 5
X, y = df_to_X_y(temp, WINDOW_SIZE)
X.shape, y.shape
# Out:
# ((70086, 5, 1), (70086,))

# %%
X_train, y_train = X[:60000], y[:60000]
X_val, y_val = X[60000:65000], y[60000:65000]
X_test, y_test = X[65000:], y[65000:]
X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape
# Out:
# ((60000, 5, 1), (60000,), (5000, 5, 1), (5000,), (5086, 5, 1), (5086,))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

model1 = Sequential()
model1.add(InputLayer((5,1)))
model1.add(LSTM(64))
model1.add(Dense(8,'relu'))
model1.add(Dense(1,'linear'))

model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 64)                16896
#
#  dense (Dense)               (None, 8)                 520
#
#  dense_1 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 17,425
# Trainable params: 17,425
# Non-trainable params: 0
# _________________________________________________________________

# %%
cp = ModelCheckpoint('model1/', save_best_only=True)
model1.compile(loss=MeanSquaredError(), optimizer =Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

model1.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10, callbacks=[cp])
# Out:
# Epoch 1/10
# 1872/1875 [============================>.] - ETA: 0s - loss: 31.0316 - root_mean_squared_error: 5.5706
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model1/assets
# INFO:tensorflow:Assets written to: model1/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fe40212fe90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 1875/1875 [==============================] - 13s 6ms/step - loss: 30.9867 - root_mean_squared_error: 5.5666 - val_loss: 1.2162 - val_root_mean_squared_error: 1.1028
# Epoch 2/10
# 1860/1875 [============================>.] - ETA: 0s - loss: 1.9888 - root_mean_squared_error: 1.4102
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model1/assets
# INFO:tensorflow:Assets written to: model1/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fe40212fe90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 1875/1875 [==============================] - 11s 6ms/step - loss: 1.9855 - root_mean_squared_error: 1.4091 - val_loss: 0.6414 - val_root_mean_squared_error: 0.8008
# Epoch 3/10
# 1874/1875 [============================>.] - ETA: 0s - loss: 0.9237 - root_mean_squared_error: 0.9611
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model1/assets
# INFO:tensorflow:Assets written to: model1/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fe40212fe90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.9236 - root_mean_squared_error: 0.9610 - val_loss: 0.5694 - val_root_mean_squared_error: 0.7546
# Epoch 4/10
# 1872/1875 [============================>.] - ETA: 0s - loss: 0.7343 - root_mean_squared_error: 0.8569
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model1/assets
# INFO:tensorflow:Assets written to: model1/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fe40212fe90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.7341 - root_mean_squared_error: 0.8568 - val_loss: 0.5311 - val_root_mean_squared_error: 0.7288
# Epoch 5/10
# 1875/1875 [==============================] - ETA: 0s - loss: 0.6845 - root_mean_squared_error: 0.8274
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model1/assets
# INFO:tensorflow:Assets written to: model1/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fe40212fe90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.6845 - root_mean_squared_error: 0.8274 - val_loss: 0.5288 - val_root_mean_squared_error: 0.7272
# Epoch 6/10
# 1865/1875 [============================>.] - ETA: 0s - loss: 0.6694 - root_mean_squared_error: 0.8182
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model1/assets
# INFO:tensorflow:Assets written to: model1/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fe40212fe90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.6683 - root_mean_squared_error: 0.8175 - val_loss: 0.5084 - val_root_mean_squared_error: 0.7130
# Epoch 7/10
# 1862/1875 [============================>.] - ETA: 0s - loss: 0.6609 - root_mean_squared_error: 0.8129
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model1/assets
# INFO:tensorflow:Assets written to: model1/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fe40212fe90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.6610 - root_mean_squared_error: 0.8130 - val_loss: 0.4999 - val_root_mean_squared_error: 0.7071
# Epoch 8/10
# 1861/1875 [============================>.] - ETA: 0s - loss: 0.6552 - root_mean_squared_error: 0.8095
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model1/assets
# INFO:tensorflow:Assets written to: model1/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fe40212fe90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.6547 - root_mean_squared_error: 0.8091 - val_loss: 0.4983 - val_root_mean_squared_error: 0.7059
# Epoch 9/10
# 1867/1875 [============================>.] - ETA: 0s - loss: 0.6506 - root_mean_squared_error: 0.8066
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model1/assets
# INFO:tensorflow:Assets written to: model1/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fe40212fe90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.6501 - root_mean_squared_error: 0.8063 - val_loss: 0.4933 - val_root_mean_squared_error: 0.7024
# Epoch 10/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.6468 - root_mean_squared_error: 0.8043 - val_loss: 0.4993 - val_root_mean_squared_error: 0.7066

# %%
from tensorflow.keras.models import load_model
model1 = load_model('model1/')

train_predictions = model1.predict(X_train).flatten()
train_results = pd.DataFrame(data = {'Train Predictions':train_predictions, 'Actuals':y_train})
train_results
# Out:
#        Train Predictions  Actuals
# 0              -9.891961    -9.67
# 1              -9.661394    -9.17
# 2              -8.714428    -8.10
# 3              -7.189301    -7.66
# 4              -7.170494    -7.04
# ...                  ...      ...
# 59995           6.002509     6.07
# 59996           7.161411     9.88
# 59997          12.214012    13.53
# 59998          16.180731    15.43
# 59999          16.486170    15.54
#
# [60000 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(train_results['Train Predictions'][:100])
plt.plot(train_results['Actuals'][:100])

# %%
val_predictions = model1.predict(X_val).flatten()
val_results = pd.DataFrame(data = {'Val Predictions':val_predictions, 'Actuals':y_val})
val_results
# Out:
#       Val Predictions  Actuals
# 0           15.510660    14.02
# 1           13.219839    13.67
# 2           13.045479    12.27
# 3           11.562094    11.19
# 4           10.436842    10.85
# ...               ...      ...
# 4995        17.423962    18.27
# 4996        17.363770    17.85
# 4997        17.207985    16.65
# 4998        15.880263    15.85
# 4999        15.092189    15.09
#
# [5000 rows x 2 columns]

# %%
plt.plot(val_results['Val Predictions'][:100])
plt.plot(val_results['Actuals'][:100])

# %%
test_predictions = model1.predict(X_test).flatten()
test_results = pd.DataFrame(data = {'test Predictions':test_predictions, 'Actuals':y_test})
test_results
# Out:
#       test Predictions  Actuals
# 0            14.432936    13.99
# 1            13.301312    13.46
# 2            12.908546    12.93
# 3            12.522911    12.43
# 4            12.075673    12.17
# ...                ...      ...
# 5081         -1.120027    -0.98
# 5082         -1.530053    -1.40
# 5083         -1.761116    -2.75
# 5084         -3.179592    -2.89
# 5085         -3.106775    -3.93
#
# [5086 rows x 2 columns]

# %%
plt.plot(test_results['test Predictions'][:100])
plt.plot(test_results['Actuals'][:100])
